# %%
import pandas as pd

# %%
data_presentados = pd.read_excel("../../data/raw/presentados/Expedientes Presentados 2017.xlsx")
data_resueltos = pd.read_excel("../../data/raw/resueltos/Expedientes Resueltos 2017.xlsx")

# %%
data_resueltos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3208 entries, 0 to 3207
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NRO. DE EXPEDIENTE     3208 non-null   object
#  1   EXPEDIENTE DE ORIGEN   3208 non-null   object
#  2   TIPO DE EXPEDIENTE     3208 non-null   object
#  3   FECHA DE PRESENTACIÓN  3208 non-null   datetime64[ns]
#  4   DENUNCIADOS            3000 non-null   object
#  5   MATERIA SPC            2489 non-null   object
#  6   F. RESOLUCIÓN          3208 non-null   datetime64[ns]
#  7   NRO. DE RESOLUCIÓN     3208 non-null   object
#  8   FORMA DE CONCLUSIÓN    3208 non-null   object
# dtypes: datetime64[ns](2), object(7)
# memory usage: 225.7+ KB

# %%
data_presentados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   INGRESO EN SALA                           2930 non-null   object
#  1   NRO. EXPEDIENTE ORIGEN                    2924 non-null   object
#  2   TIPO EXPEDIENTE                           2930 non-null   object
#  3   FECHA DE PRESENTACION                     2930 non-null   datetime64[ns]
#  4   DENUNCIADO(S)                             2805 non-null   object
#  5   TIPO Y NUMERO DE DOCUMENTO DENUNCIADO(S)  2799 non-null   object
#  6   MATERIA                                   2275 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 160.4+ KB

# %%
data_presentados.head()
# Out:
#            INGRESO EN SALA      NRO. EXPEDIENTE ORIGEN TIPO EXPEDIENTE  \
# 0      0001-2017/SPC-QUEJA  0237-2016/CPC-INDECOPI-PIU           QUEJA
# 1      0002-2017/SPC-QUEJA  0312-2015/CPC-INDECOPI-AQP           QUEJA
# 2  0003-2017/SPC-APELACION  0147-2016/CPC-INDECOPI-LAM       APELACION
# 3  0004-2017/SPC-APELACION  0121-2016/CPC-INDECOPI-LAM       APELACION
# 4  0005-2017/SPC-APELACION  0033-2015/CPC-INDECOPI-LAM       APELACION
#
#   FECHA DE PRESENTACION                                      DENUNCIADO(S)  \
# 0            2017-01-02  COMISION DE LA OFICINA REGIONAL DEL INDECOPI D...
# 1            2017-01-03  COMISION DE LA OFICINA REGIONAL DEL INDECOPI D...
# 2            2017-01-02                           TOURS ANGEL DIVINO S.A.C
# 3            2017-01-02                 UNIVERSIDAD PARTICULAR DE CHICLAYO
# 4            2017-01-02                 UNIVERSIDAD PARTICULAR DE CHICLAYO
#
#   TIPO Y NUMERO DE DOCUMENTO DENUNCIADO(S)                  MATERIA
# ...

# %%
data_resueltos.head()
# Out:
#         NRO. DE EXPEDIENTE        EXPEDIENTE DE ORIGEN TIPO DE EXPEDIENTE  \
# 0  2624-2016/SPC-APELACION               1000-2014/CC1          APELACION
# 1  2626-2016/SPC-APELACION               0080-2015/CC1          APELACION
# 2  2657-2016/SPC-APELACION               1352-2015/CC1          APELACION
# 3  2658-2016/SPC-APELACION               1409-2015/CC1          APELACION
# 4  2711-2016/SPC-APELACION  0387-2015/CPC-INDECOPI-AQP          APELACION
#
#   FECHA DE PRESENTACIÓN                                      DENUNCIADOS  \
# 0            2016-07-12                           SCOTIABANK PERÚ S.A.A.
# 1            2016-07-12  BANCO INTERNACIONAL DEL PERÚ S.A.A. - INTERBANK
# 2            2016-07-14            BANCO INTERAMERICANO DE FINANZAS S.A.
# 3            2016-07-14                           SCOTIABANK PERÚ S.A.A.
# 4            2016-07-19   BANCO INTERNACIONAL DEL PERÚ S.A.A.- INTERBANK
#
#                         MATERIA SPC F. RESOLUCIÓN NRO. DE RESOLUCIÓN  \
# ...
