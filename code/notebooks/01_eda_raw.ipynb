# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/staging/expedientes_merged.csv")

# %%
df.head(10)
# Out:
#             NRO_EXPEDIENTE          EXPEDIENTE_ORIGEN_pres  \
# 0      0001-2017/SPC-QUEJA      0237-2016/CPC-INDECOPI-PIU
# 1      0002-2017/SPC-QUEJA      0312-2015/CPC-INDECOPI-AQP
# 2  0003-2017/SPC-APELACION      0147-2016/CPC-INDECOPI-LAM
# 3  0004-2017/SPC-APELACION      0121-2016/CPC-INDECOPI-LAM
# 4  0005-2017/SPC-APELACION      0033-2015/CPC-INDECOPI-LAM
# 5   0006-2017/SPC-REVISION  0011-2016/PS0-INDECOPI-LAM-LCC
# 6  0007-2017/SPC-APELACION                   0334-2016/CC2
# 7  0008-2017/SPC-APELACION                   1054-2016/CC2
# 8  0009-2017/SPC-APELACION                   0177-2016/CC2
# 9   0010-2017/SPC-REVISION                   0432-2016/PS3
#
#   TIPO_EXPEDIENTE_pres FECHA_PRESENTACION_pres  \
# 0                QUEJA              2017-01-02
# 1                QUEJA              2017-01-03
# 2            APELACION              2017-01-02
# 3            APELACION              2017-01-02
# 4            APELACION              2017-01-02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14231 entries, 0 to 14230
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   NRO_EXPEDIENTE                            14231 non-null  object
#  1   EXPEDIENTE_ORIGEN_pres                    14206 non-null  object
#  2   TIPO_EXPEDIENTE_pres                      14231 non-null  object
#  3   FECHA_PRESENTACION_pres                   14231 non-null  object
#  4   DENUNCIADOS_pres                          13762 non-null  object
#  5   TIPO Y NUMERO DE DOCUMENTO DENUNCIADO(S)  13758 non-null  object
#  6   MATERIA_pres                              11774 non-null  object
#  7   año_pres                                  14231 non-null  int64
#  8   EXPEDIENTE_ORIGEN_res                     13402 non-null  object
#  9   TIPO_EXPEDIENTE_res                       13402 non-null  object
# ...
