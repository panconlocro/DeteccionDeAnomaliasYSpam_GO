# %%
import pandas as pd

# %%
data = pd.read_csv("../../data/synthetic/expedientes_1M.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   NRO_EXPEDIENTE           1000000 non-null  object
#  1   EXPEDIENTE_ORIGEN_pres   998250 non-null   object
#  2   TIPO_EXPEDIENTE_pres     1000000 non-null  object
#  3   FECHA_PRESENTACION_pres  1000000 non-null  object
#  4   DENUNCIADOS_pres         967653 non-null   object
#  5   DOC_DENUNCIADO           965779 non-null   object
#  6   MATERIA_pres             827586 non-null   object
#  7   año_pres                 1000000 non-null  int64
#  8   FECHA_RESOLUCION         951870 non-null   object
#  9   NRO_RESOLUCION           951870 non-null   object
#  10  FORMA_CONCLUSION         951870 non-null   object
#  11  año_res                  951870 non-null   float64
#  12  RES_MATCH_SOURCE         1000000 non-null  object
# ...

# %%
data.head()
# Out:
#          NRO_EXPEDIENTE      EXPEDIENTE_ORIGEN_pres TIPO_EXPEDIENTE_pres  \
# 0  1425-2018/SPC-131881               1285-2017/CC1            APELACION
# 1  0953-2021/SPC-391135               0553-2020/CC2                QUEJA
# 2  0120-2021/SPC-710807               0702-2019/CC2                QUEJA
# 3  1886-2018/SPC-525643               1412-2017/CC2            APELACION
# 4  1231-2017/SPC-557132  0216-2016/CPC-INDECOPI-ICA            APELACION
#
#   FECHA_PRESENTACION_pres                        DENUNCIADOS_pres  \
# 0              2018-05-11                     SCOTIABANK PERU SAA
# 1              2021-05-23  COMISION DE PROTECCION AL CONSUMIDOR 2
# 2              2021-01-16  COMISION DE PROTECCION AL CONSUMIDOR 2
# 3              2018-07-07                         LOS PORTALES SA
# 4              2017-06-11                                     NaN
#
#   DOC_DENUNCIADO                       MATERIA_pres  año_pres  \
# 0    20100043140                  PRESTAMO PERSONAL      2018
# ...

# %%
# Cuantos registros tienen ES_SPAM = 1
data[data["ES_SPAM"] == 1].shape[0]
# Out:
# 220000

# %%
# revisar los valores unicos de TIPO_SPAM
data["TIPO_SPAM"].unique()
# Out:
# array(['normal', 'queja_duplicada', 'denunciado_fantasma',
#        'bombardeo_tiempo', 'rafaga_nocturna'], dtype=object)

# %%
# cuantos hay de cada tipo de TIPO_SPAM
data.groupby("TIPO_SPAM").size()
# Out:
# TIPO_SPAM
# bombardeo_tiempo        80000
# denunciado_fantasma     30000
# normal                 780000
# queja_duplicada         70000
# rafaga_nocturna         40000
# dtype: int64
