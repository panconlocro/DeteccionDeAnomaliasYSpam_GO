# %%
import polars as pl
import pandas as pd

# %%
# leer los archivos para la revision

data_s = pd.read_csv("../../data/synthetic/expedientes_synthetic.csv")
data_c = pd.read_csv("../../data/clean/expedientes_clean.csv")

# %%
# informacion general de los datos
data_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969306 entries, 0 to 969305
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   DENUNCIADOS_pres         969306 non-null  object
#  1   DOC_DENUNCIADO           964982 non-null  object
#  2   EXPEDIENTE_ORIGEN_pres   967594 non-null  object
#  3   FECHA_PRESENTACION_pres  969306 non-null  object
#  4   FECHA_RESOLUCION         921035 non-null  object
#  5   FORMA_CONCLUSION         921035 non-null  object
#  6   MATERIA_pres             799213 non-null  object
#  7   NRO_EXPEDIENTE           969306 non-null  object
#  8   NRO_RESOLUCION           921035 non-null  object
#  9   RES_MATCH_SOURCE         969306 non-null  object
#  10  TIPO_EXPEDIENTE_pres     969306 non-null  object
#  11  año_pres                 969306 non-null  int64
#  12  año_res                  921035 non-null  float64
#  13  TIMESTAMP                969306 non-null  object
#  14  DETALLE_QUEJA            969306 non-null  object
#  15  ES_SPAM                  969306 non-null  int64
#  16  SPAM_TAGS                176983 non-null  object
#  17  SPAM_SCORE               969306 non-null  float64
# dtypes: float64(2), int64(2), object(14)
# memory usage: 133.1+ MB

# %%
data_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14231 entries, 0 to 14230
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NRO_EXPEDIENTE           14231 non-null  object
#  1   EXPEDIENTE_ORIGEN_pres   14206 non-null  object
#  2   TIPO_EXPEDIENTE_pres     14231 non-null  object
#  3   FECHA_PRESENTACION_pres  14231 non-null  object
#  4   DENUNCIADOS_pres         13759 non-null  object
#  5   DOC_DENUNCIADO           13746 non-null  object
#  6   MATERIA_pres             11774 non-null  object
#  7   año_pres                 14231 non-null  int64
#  8   FECHA_RESOLUCION         13543 non-null  object
#  9   NRO_RESOLUCION           13543 non-null  object
#  10  FORMA_CONCLUSION         13543 non-null  object
#  11  año_res                  13543 non-null  float64
#  12  RES_MATCH_SOURCE         14231 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.4+ MB

# %%
# Vista inicial
data_s.sample(5)
# Out:
#                                          DENUNCIADOS_pres DOC_DENUNCIADO  \
# 254244                                     VILLA CLUB SAC    20492390098
# 241742                                   PIRATA TOURS SAC    20602678793
# 650047              UNITED AIRLINES INC SUCURSAL DEL PERU    20297995635
# 949194  CAJA MUNICIPAL DE AHORRO Y CREDITO CUSCO SA - ...    20114839176
# 923843             EMPRESA DE TRANSPORTES FLORES HNOS SRL    20119407738
#
#                 EXPEDIENTE_ORIGEN_pres FECHA_PRESENTACION_pres  \
# 254244                   1102-2018/CC2              2020-11-03
# 241742  0005-2019/CPC-INDECOPI-SAM-SIA              2019-06-28
# 650047                   0649-2016/CC2              2018-08-08
# 949194      0073-2019/CPC-INDECOPI-CUS              2020-02-24
# 923843      0139-2017/CPC-INDECOPI-ICA              2018-04-20
#
#        FECHA_RESOLUCION FORMA_CONCLUSION                       MATERIA_pres  \
# 254244       2021-03-16         CONFIRMA  CONSTRUCCION Y VENTA DE INMUEBLES
# 241742       2019-10-23       CONSENTIDO  ACTIVIDADES DE AGENCIAS DE VIAJES
# 650047       2019-02-11         CONFIRMA            TRANSPORTE DE PASAJEROS
# 949194       2020-10-14         CONFIRMA                  CUENTA DE AHORROS
# 923843       2018-10-15         CONFIRMA                        ENCOMIENDAS
#
#                  NRO_EXPEDIENTE     NRO_RESOLUCION RES_MATCH_SOURCE  \
# 254244  1505-2020/SPC-APELACION  00000583-2021/SPC              nro
# 241742  1744-2019/SPC-APELACION  00002953-2019/SPC              nro
# 650047  2212-2018/SPC-APELACION  00000375-2019/SPC              nro
# 949194  0548-2020/SPC-APELACION  00001843-2020/SPC              nro
# 923843  1227-2018/SPC-APELACION  00002804-2018/SPC              nro
#
#        TIPO_EXPEDIENTE_pres  año_pres  año_res            TIMESTAMP  \
# 254244            APELACION      2020   2021.0  2020-11-03 16:19:11
# 241742            APELACION      2019   2019.0  2019-06-28 18:26:38
# 650047            APELACION      2018   2019.0  2018-08-08 08:28:41
# 949194            APELACION      2020   2020.0  2020-02-24 10:44:25
# 923843            APELACION      2018   2018.0  2018-04-20 11:02:46
#
#                                             DETALLE_QUEJA  ES_SPAM SPAM_TAGS  \
# 254244  Deseo registrar una denuncia contra VILLA CLUB...        0       NaN
# 241742  Quiero reportar un problema contra PIRATA TOUR...        0       NaN
# 650047  Deseo registrar una denuncia contra UNITED AIR...        0       NaN
# 949194  Deseo registrar una denuncia contra CAJA MUNIC...        0       NaN
# 923843  Interpongo un reclamo contra EMPRESA DE TRANSP...        0       NaN
#
#         SPAM_SCORE
# 254244        0.19
# 241742        0.08
# 650047        0.12
# 949194        0.17
# 923843        0.04

# %% [markdown]
# ### Chiqui liempieza de la data sintetica

# %%
# Eliminar las filas sin valor

## Eiminar las columnas año_res y año_pres
data_s = data_s.drop(columns=["año_pres", "año_res"])

## Eliminar columan RES_MATCH_SOURCE generada en el merge
data_s = data_s.drop(columns=["RES_MATCH_SOURCE"])

# %%
# Cambiar nombres de columnas para facilitar la comprencion
data_s = data_s.rename(columns={
    "DENUNCIADOS_pres": "DENUNCIADOS",
    "TIPO_EXPEDIENTE_pres": "TIPO_EXPEDIENTE",
    "MATERIA_pres":"MATERIA",
    "FECHA_PRESENTACION_pres":"FECHA_PRESENTACION",
})

# %%
# reemplazar el csv sintetico con el limpio
data_s.to_csv("../../data/synthetic/expedientes_synthetic.csv", index=False)

# %%
data_s.sample(5)
# Out:
#                                               DENUNCIADOS  \
# 766669                                SCOTIABANK PERU SAA
# 497873                            Servicios Financiero SA
# 944225  MAPFRE PERU VIDA COMPANIA DE SEGUROS Y REASEGU...
# 51471   COOPERATIVA DE AHORRO Y CREDITO SAN ISIDRO DE ...
# 497684                          BBVA BANCO CONTINENTAL SA
#
#                          DOC_DENUNCIADO      EXPEDIENTE_ORIGEN_pres  \
# 766669                      20100043140  0263-2017/CPC-INDECOPI-LAM
# 497873                      20133840533               0504-2021/CC2
# 944225  20100043140 / RUC : 20418896915               1034-2019/CC1
# 51471                       20137995477               0998-2019/CC1
# 497684                      20100130204  0296-2016/PS0-INDECOPI-PIU
#
#        FECHA_PRESENTACION FECHA_RESOLUCION FORMA_CONCLUSION  \
# 766669         2018-03-02       2018-08-22         CONFIRMA
# 497873         2021-07-21       2021-07-27     IMPROCEDENTE
# 944225         2020-08-14       2021-01-13       CONSENTIDO
# 51471          2020-03-04       2020-10-14         CONFIRMA
# 497684         2017-01-13       2017-01-31     IMPROCEDENTE
#
#                                           MATERIA           NRO_EXPEDIENTE  \
# 766669                         CREDITO DE CONSUMO  0661-2018/SPC-APELACION
# 497873                                        NaN      1463-2021/SPC-QUEJA
# 944225  CREDITO DE CONSUMO /SEGURO DE DESGRAVAMEN  0891-2020/SPC-APELACION
# 51471                          CREDITO DE CONSUMO  0613-2020/SPC-APELACION
# 497684                         TARJETA DE CREDITO   0159-2017/SPC-REVISION
#
#            NRO_RESOLUCION TIPO_EXPEDIENTE            TIMESTAMP  \
# 766669  00002155-2018/SPC       APELACION  2018-03-02 15:37:08
# 497873  00001705-2021/SPC           QUEJA  2021-07-21 08:34:46
# 944225  00000072-2021/SPC       APELACION  2020-08-14 16:02:18
# 51471   00001844-2020/SPC       APELACION  2020-03-04 16:58:48
# 497684  00000570-2017/SPC        REVISION  2017-01-13 09:52:01
#
#                                             DETALLE_QUEJA  ES_SPAM  \
# 766669  Interpongo un reclamo contra SCOTIABANK PERU S...        0
# 497873  Interpongo un reclamo contra COMISION DE PROTE...        1
# 944225  Presento una queja contra MAPFRE PERU VIDA COM...        0
# 51471   Interpongo un reclamo contra COOPERATIVA DE AH...        0
# 497684  Deseo registrar una denuncia contra BBVA BANCO...        0
#
#                       SPAM_TAGS  SPAM_SCORE
# 766669                      NaN        0.24
# 497873  fake_entity;fake_entity        0.71
# 944225                      NaN        0.02
# 51471                       NaN        0.16
# 497684                      NaN        0.18

# %%
data_s.sample(5)
# Out:
#                                    DENUNCIADOS DOC_DENUNCIADO  \
# 782011               BANCO DE CREDITO DEL PERU    20100047218
# 238394  BANCO INTERNACIONAL DEL PERU-INTERBANK    20100053455
# 447536               Consorcio Financiero EIRL    20133840533
# 780630             MITSUI AUTO FINANCE PERU SA    20375361991
# 462619                 INNOVA INMOBILIARIE SAC    20567263739
#
#             EXPEDIENTE_ORIGEN_pres FECHA_PRESENTACION FECHA_RESOLUCION  \
# 782011  0063-2018/CPC-INDECOPI-ICA         2018-12-26       2019-07-02
# 238394               1137-2016/CC1         2017-08-29       2018-02-14
# 447536  0181-2018/CPC-INDECOPI-AQP         2018-12-05       2018-12-14
# 780630               0208-2021/CC1         2021-11-26              NaN
# 462619  0062-2018/CPC-INDECOPI-PIU         2018-09-06       2019-02-25
#
#        FORMA_CONCLUSION                            MATERIA  \
# 782011         CONFIRMA                 CREDITO DE CONSUMO
# 238394         CONFIRMA                CREDITO HIPOTECARIO
# 447536     IMPROCEDENTE                                NaN
# 780630              NaN           VENTA DE OTROS PRODUCTOS
# 462619         CONFIRMA  CONSTRUCCION Y VENTA DE INMUEBLES
#
#                  NRO_EXPEDIENTE     NRO_RESOLUCION TIPO_EXPEDIENTE  \
# 782011  3361-2018/SPC-APELACION  00001787-2019/SPC       APELACION
# 238394  1857-2017/SPC-APELACION  00000291-2018/SPC       APELACION
# 447536      3226-2018/SPC-QUEJA  00003528-2018/SPC           QUEJA
# 780630  2515-2021/SPC-APELACION                NaN       APELACION
# 462619  2428-2018/SPC-APELACION  00000493-2019/SPC       APELACION
#
#                   TIMESTAMP  \
# 782011  2018-12-26 13:10:31
# 238394  2017-08-29 10:56:34
# 447536  2018-12-05 02:10:00
# 780630  2021-11-26 11:47:41
# 462619  2018-09-06 20:29:53
#
#                                             DETALLE_QUEJA  ES_SPAM  \
# 782011  Deseo registrar una denuncia contra BANCO DE C...        0
# 238394  Interpongo un reclamo contra BANCO INTERNACION...        0
# 447536  Presento una queja contra COMISION DE PROTECCI...        1
# 780630  Presento una queja contra MITSUI AUTO FINANCE ...        0
# 462619  PRESENTO UNA QUEJA CONTRA INNOVA INMOBILIARIE ...        0
#
#                                         SPAM_TAGS  SPAM_SCORE
# 782011                                        NaN        0.05
# 238394                                        NaN        0.23
# 447536  night_activity;night_activity;fake_entity        0.94
# 780630                                        NaN        0.00
# 462619                                        NaN        0.25
