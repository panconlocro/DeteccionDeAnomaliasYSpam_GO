# %%
import polars as pl
import pandas as pd

# %%
# leer los archivos para la revision

data_s = pd.read_csv("../../data/synthetic/expedientes_synthetic.csv")
data_c = pd.read_csv("../../data/clean/expedientes_clean.csv")

# %%
# informacion general de los datos
data_s.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 969115 entries, 0 to 969114
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   DENUNCIADOS_pres         969115 non-null  str
#  1   DOC_DENUNCIADO           964902 non-null  str
#  2   EXPEDIENTE_ORIGEN_pres   967316 non-null  str
#  3   FECHA_PRESENTACION_pres  969115 non-null  str
#  4   FECHA_RESOLUCION         921247 non-null  str
#  5   FORMA_CONCLUSION         921247 non-null  str
#  6   MATERIA_pres             799005 non-null  str
#  7   NRO_EXPEDIENTE           969115 non-null  str
#  8   NRO_RESOLUCION           921247 non-null  str
#  9   RES_MATCH_SOURCE         969115 non-null  str
#  10  TIPO_EXPEDIENTE_pres     969115 non-null  str
#  11  año_pres                 969115 non-null  int64
#  12  año_res                  921247 non-null  float64
#  13  TIMESTAMP                969115 non-null  str
#  14  DETALLE_QUEJA            969115 non-null  str
#  15  ES_SPAM                  969115 non-null  int64
#  16  SPAM_TAGS                176746 non-null  str
#  17  SPAM_SCORE               969115 non-null  float64
# dtypes: float64(2), int64(2), str(14)
# memory usage: 133.1 MB

# %%
data_c.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14231 entries, 0 to 14230
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NRO_EXPEDIENTE           14231 non-null  str
#  1   EXPEDIENTE_ORIGEN_pres   14206 non-null  str
#  2   TIPO_EXPEDIENTE_pres     14231 non-null  str
#  3   FECHA_PRESENTACION_pres  14231 non-null  str
#  4   DENUNCIADOS_pres         13759 non-null  str
#  5   DOC_DENUNCIADO           13746 non-null  str
#  6   MATERIA_pres             11774 non-null  str
#  7   año_pres                 14231 non-null  int64
#  8   FECHA_RESOLUCION         13543 non-null  str
#  9   NRO_RESOLUCION           13543 non-null  str
#  10  FORMA_CONCLUSION         13543 non-null  str
#  11  año_res                  13543 non-null  float64
#  12  RES_MATCH_SOURCE         14231 non-null  str
# dtypes: float64(1), int64(1), str(11)
# memory usage: 1.4 MB

# %%
# Vista inicial
data_s.sample(5)
# Out:
#                                          DENUNCIADOS_pres  \
# 856855  PROMOTORA INMOBILIARIA MONTERRICO SAC / INMOBI...
# 349601    FINANCIERA CONFIANZA SAA - FINANCIERA CONFIANZA
# 339704                          Corporación Financiero SA
# 126007                                    Grupo Andino SA
# 401000                                    BANCO PICHINCHA
#
#                                            DOC_DENUNCIADO  \
# 856855                    20546996116 / RUC : 20548300178
# 349601                                        20228319768
# 339704  20100130204 / RUC : 20493058348 / RUC : 206012...
# 126007                                        20100105862
# 401000                                        20100105862
#
#             EXPEDIENTE_ORIGEN_pres FECHA_PRESENTACION_pres FECHA_RESOLUCION  \
# 856855               0083-2017/PS3              2017-03-17       2017-03-28
# 349601  0141-2016/CPC-INDECOPI-AQP              2017-12-27       2018-06-20
# 339704               0672-2017/CC1              2018-03-21       2018-09-17
# 126007               0233-2019/CC1              2019-08-08       2019-12-04
# 401000               0776-2018/CC1              2018-11-12       2019-03-25
#
#                               FORMA_CONCLUSION  \
# 856855  DEFINICION DE CONTIENDA DE COMPETENCIA
# 349601                                  REVOCA
# 339704                                CONFIRMA
# 126007                                CONFIRMA
# 401000                                CONFIRMA
#
#                                              MATERIA_pres  \
# 856855                  CONSTRUCCION Y VENTA DE INMUEBLES
# 349601                                 CREDITO DE CONSUMO
# 339704  CREDITO DE CONSUMO /ASESORIA JURIDICA LEGAL /C...
# 126007                                 TARJETA DE CREDITO
# 401000                                  PRESTAMO PERSONAL
#
#                  NRO_EXPEDIENTE     NRO_RESOLUCION RES_MATCH_SOURCE  \
# 856855         0676-2017/SPC-CC  00001245-2017/SPC              nro
# 349601  2888-2017/SPC-APELACION  00001510-2018/SPC              nro
# 339704  0908-2018/SPC-APELACION  00002427-2018/SPC              nro
# 126007  2022-2019/SPC-APELACION  00003462-2019/SPC              nro
# 401000  3000-2018/SPC-APELACION  00000793-2019/SPC              nro
#
#             TIPO_EXPEDIENTE_pres  año_pres  año_res            TIMESTAMP  \
# 856855  CONTIENDA DE COMPETENCIA      2017   2017.0  2017-03-17 18:37:29
# 349601                 APELACION      2017   2018.0  2017-12-27 11:37:48
# 339704                 APELACION      2018   2018.0  2018-03-21 14:00:10
# 126007                 APELACION      2019   2019.0  2019-08-08 19:21:54
# 401000                 APELACION      2018   2019.0  2018-11-12 08:06:37
#
#                                             DETALLE_QUEJA  ES_SPAM  \
# 856855  Interpongo un reclamo contra PROMOTORA INMOBIL...        0
# 349601  Presento una queja contra FINANCIERA CONFIANZA...        0
# 339704  deseo registrar una denuncia contra four capit...        1
# 126007  Presento una queja contra BANCO PICHINCHA por ...        1
# 401000  Quiero reportar un problema contra BANCO PICHI...        0
#
#                                         SPAM_TAGS  SPAM_SCORE
# 856855                                        NaN        0.02
# 349601                                        NaN        0.17
# 339704  duplicate_text;fake_entity;duplicate_text        0.80
# 126007                                fake_entity        0.99
# 401000                                        NaN        0.27

# %% [markdown]
# ### Chiqui liempieza de la data sintetica

# %%
# Eliminar las filas sin valor

## Eiminar las columnas año_res y año_pres
data_s = data_s.drop(columns=["año_pres", "año_res"])

## Eliminar columan RES_MATCH_SOURCE generada en el merge
data_s = data_s.drop(columns=["RES_MATCH_SOURCE"])

# %%
# Cambiar nombres de columnas para facilitar la comprencion
data_s = data_s.rename(columns={
    "DENUNCIADOS_pres": "DENUNCIADOS",
    "TIPO_EXPEDIENTE_pres": "TIPO_EXPEDIENTE",
    "MATERIA_pres":"MATERIA",
    "FECHA_PRESENTACION_pres":"FECHA_PRESENTACION",
})

# %%
# reemplazar el csv sintetico con el limpio
data_s.to_csv("../../data/synthetic/expedientes_synthetic.csv", index=False)

# %%
data_s.sample(5)
# Out:
#                                               DENUNCIADOS  \
# 929230      UNIVERSIDAD PERUANA DE CIENCIAS APLICADAS SAC
# 386605                         RIMAC SEGUROS Y REASEGUROS
# 230841  AUTOFONDO SAC / AUTONIZA SAC / GENERAL MOTORS ...
# 785062             COMISION DE PROTECCION AL CONSUMIDOR 2
# 620953  CEP PERUANO CHINO JUAN XXIII / FRANCISCANOS PA...
#
#                                            DOC_DENUNCIADO  \
# 929230                                        20211614545
# 386605                                        20202380621
# 230841  20261126568 / RUC : 20516062305 / RUC : 206017...
# 785062                                        20133840533
# 620953                    20156754898 / RUC : 20250185759
#
#        EXPEDIENTE_ORIGEN_pres FECHA_PRESENTACION FECHA_RESOLUCION  \
# 929230          1209-2017/CC2         2018-01-31       2018-08-08
# 386605          1445-2018/CC1         2019-09-02       2020-01-06
# 230841          0249-2019/CC2         2019-12-17       2020-10-22
# 785062          0529-2019/CC2         2019-07-11       2019-07-22
# 620953      0444-2019/ILN-CPC         2021-03-19       2021-09-15
#
#        FORMA_CONCLUSION                                            MATERIA  \
# 929230         CONFIRMA                             SERVICIOS DE ENSEÑANZA
# 386605         CONFIRMA                                               SOAT
# 230841         CONFIRMA  MANTENIMIENTO Y REPARACION DE VEHICULOS AUTOMO...
# 785062        INFUNDADA                                                NaN
# 620953       CONSENTIDO            SERVICIOS DE ENSEÑANZA /OTROS SERVICIOS
#
#                  NRO_EXPEDIENTE     NRO_RESOLUCION  TIPO_EXPEDIENTE  \
# 929230         0281-2018/SPC-MC  00002009-2018/SPC  MEDIDA CAUTELAR
# 386605  2202-2019/SPC-APELACION  00000026-2020/SPC        APELACION
# 230841  3018-2019/SPC-APELACION  00001918-2020/SPC        APELACION
# 785062      1848-2019/SPC-QUEJA  00002010-2019/SPC            QUEJA
# 620953  0483-2021/SPC-APELACION  00002055-2021/SPC        APELACION
#
#                   TIMESTAMP  \
# 929230  2018-01-31 16:09:53
# 386605  2019-09-02 13:55:04
# 230841  2019-12-17 14:38:33
# 785062  2019-07-11 14:34:26
# 620953  2021-03-19 15:30:28
#
#                                             DETALLE_QUEJA  ES_SPAM SPAM_TAGS  \
# 929230  Quiero reportar un problema contra UNIVERSIDAD...        0       NaN
# 386605  PRESENTO UNA QUEJA CONTRA RIMAC SEGUROS Y REAS...        0       NaN
# 230841  Interpongo un reclamo contra AUTOFONDO SAC / A...        0       NaN
# 785062  Interpongo un reclamo contra COMISION DE PROTE...        0       NaN
# 620953  Interpongo un reclamo contra CEP PERUANO CHINO...        0       NaN
#
#         SPAM_SCORE
# 929230        0.06
# 386605        0.00
# 230841        0.10
# 785062        0.11
# 620953        0.23

# %%
data_s.sample(5)
# Out:
#                                          DENUNCIADOS  \
# 492206  BANCO INTERNACIONAL DEL PERU SAA - INTERBANK
# 328678               DERCO PERU SA / DERCOCENTER SAC
# 776083                               PANDERO SA EAFC
# 726917                 GERENCIA DE PROYECTOS R&R SAC
# 46486       MASS AUTOMOTRIZ SA / KIA IMPORT PERU SAC
#
#                          DOC_DENUNCIADO      EXPEDIENTE_ORIGEN_pres  \
# 492206                      20100053455               0235-2015/CC1
# 328678  20344877158 / RUC : 20548527113  0214-2017/CPC-INDECOPI-AQP
# 776083                      20100115663  0411-2016/CPC-INDECOPI-AQP
# 726917                      20559671640  0364-2017/CPC-INDECOPI-LAL
# 46486   20100951232 / RUC : 20472468147               1388-2012/CPC
#
#        FECHA_PRESENTACION FECHA_RESOLUCION FORMA_CONCLUSION  \
# 492206         2017-02-23       2017-07-18          NULIDAD
# 328678         2021-08-25       2018-10-17         CONFIRMA
# 776083         2017-06-23       2017-11-10           REVOCA
# 726917         2019-03-14       2019-09-09       CONSENTIDO
# 46486          2017-09-11       2018-03-21           REVOCA
#
#                                                   MATERIA  \
# 492206                                 CREDITO DE CONSUMO
# 328678  VENTA DE VEHICULOS AUTOMOTORES Y MOTOCICLETAS ...
# 776083                                  PRESTAMO PERSONAL
# 726917                  CONSTRUCCION Y VENTA DE INMUEBLES
# 46486   VENTA DE VEHICULOS AUTOMOTORES Y MOTOCICLETAS ...
#
#                  NRO_EXPEDIENTE     NRO_RESOLUCION TIPO_EXPEDIENTE  \
# 492206  0508-2017/SPC-APELACION  00002240-2017/SPC       APELACION
# 328678  1759-2021/SPC-APELACION  00002832-2018/SPC       APELACION
# 776083  1323-2017/SPC-APELACION  00003194-2017/SPC       APELACION
# 726917  0676-2019/SPC-APELACION  00002446-2019/SPC       APELACION
# 46486   1924-2017/SPC-APELACION  00000594-2018/SPC       APELACION
#
#                   TIMESTAMP  \
# 492206  2017-02-23 14:56:52
# 328678  2021-08-25 15:22:30
# 776083  2017-06-23 11:02:15
# 726917  2019-03-14 09:30:25
# 46486   2017-09-11 15:19:50
#
#                                             DETALLE_QUEJA  ES_SPAM SPAM_TAGS  \
# 492206  Deseo registrar una denuncia contra BANCO INTE...        0       NaN
# 328678  Quiero reportar un problema contra DERCO PERU ...        0       NaN
# 776083  Quiero reportar un problema contra PANDERO SA ...        0       NaN
# 726917  Presento una queja contra GERENCIA DE PROYECTO...        0       NaN
# 46486   Quiero reportar un problema contra MASS AUTOMO...        0       NaN
#
#         SPAM_SCORE
# 492206        0.21
# 328678        0.14
# 776083        0.08
# 726917        0.27
# 46486         0.20
