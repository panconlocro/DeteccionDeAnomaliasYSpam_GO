# %%
import polars as pl
import pandas as pd

# %%
# leer los archivos para la revision

data_s = pd.read_csv("../../data/synthetic/expedientes_synthetic.csv")
data_c = pd.read_csv("../../data/clean/expedientes_clean.csv")

# %%
# informacion general de los datos
data_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969245 entries, 0 to 969244
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   DENUNCIADOS_pres         969245 non-null  object
#  1   DOC_DENUNCIADO           965126 non-null  object
#  2   EXPEDIENTE_ORIGEN_pres   967500 non-null  object
#  3   FECHA_PRESENTACION_pres  969245 non-null  object
#  4   FECHA_RESOLUCION         921454 non-null  object
#  5   FORMA_CONCLUSION         921454 non-null  object
#  6   MATERIA_pres             798513 non-null  object
#  7   NRO_EXPEDIENTE           969245 non-null  object
#  8   NRO_RESOLUCION           921454 non-null  object
#  9   RES_MATCH_SOURCE         969245 non-null  object
#  10  TIPO_EXPEDIENTE_pres     969245 non-null  object
#  11  año_pres                 969245 non-null  int64
#  12  año_res                  921454 non-null  float64
# ...

# %%
data_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14231 entries, 0 to 14230
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NRO_EXPEDIENTE           14231 non-null  object
#  1   EXPEDIENTE_ORIGEN_pres   14206 non-null  object
#  2   TIPO_EXPEDIENTE_pres     14231 non-null  object
#  3   FECHA_PRESENTACION_pres  14231 non-null  object
#  4   DENUNCIADOS_pres         13759 non-null  object
#  5   DOC_DENUNCIADO           13746 non-null  object
#  6   MATERIA_pres             11774 non-null  object
#  7   año_pres                 14231 non-null  int64
#  8   FECHA_RESOLUCION         13543 non-null  object
#  9   NRO_RESOLUCION           13543 non-null  object
#  10  FORMA_CONCLUSION         13543 non-null  object
#  11  año_res                  13543 non-null  float64
#  12  RES_MATCH_SOURCE         14231 non-null  object
# dtypes: float64(1), int64(1), object(11)
# ...

# %%
# Vista inicial
data_s.sample(5)
# Out:
#                                          DENUNCIADOS_pres  \
# 284722   SALA ESPECIALIZADA EN PROCEDIMIENTOS CONCURSALES
# 370328                           AUTOVENTAS GRAN PRIX SRL
# 447681             COMISION DE PROTECCION AL CONSUMIDOR 3
# 623043  IBERIA LINEAS AEREAS DE ESPANA SOCIEDAD ANONIM...
# 348768  MAPFRE PERU COMPANIA DE SEGUROS Y REASEGUROS S...
#
#                          DOC_DENUNCIADO      EXPEDIENTE_ORIGEN_pres  \
# 284722                      20133840533                         NaN
# 370328                      20393579413  0102-2019/CPC-INDECOPI-LOR
# 447681                      20133840533           0135-2019/CC3-SIA
# 623043                      20100041449               0409-2020/CC2
# 348768  20100043140 / RUC : 20202380621               0055-2019/CC1
#
#        FECHA_PRESENTACION_pres FECHA_RESOLUCION FORMA_CONCLUSION  \
# 284722              2017-12-05       2017-12-13        INFUNDADA
# 370328              2021-01-05       2021-05-27       CONSENTIDO
# ...

# %% [markdown]
# ### Chiqui liempieza de la data sintetica

# %%
# Eliminar las filas sin valor

## Eiminar las columnas año_res y año_pres
data_s = data_s.drop(columns=["año_pres", "año_res"])

## Eliminar columan RES_MATCH_SOURCE generada en el merge
data_s = data_s.drop(columns=["RES_MATCH_SOURCE"])

# %%
# Cambiar nombres de columnas para facilitar la comprencion
data_s = data_s.rename(columns={
    "DENUNCIADOS_pres": "DENUNCIADOS",
    "TIPO_EXPEDIENTE_pres": "TIPO_EXPEDIENTE",
    "MATERIA_pres":"MATERIA",
    "FECHA_PRESENTACION_pres":"FECHA_PRESENTACION",
})

# %%
# reemplazar el csv sintetico con el limpio
data_s.to_csv("../../data/synthetic/expedientes_synthetic.csv", index=False)

# %%
data_s.sample(5)
# Out:
#                                  DENUNCIADOS DOC_DENUNCIADO  \
# 209492               TRANSPORTES EL PINO SAC    20502324927
# 922812             BANCO DE CREDITO DEL PERU    20100047218
# 230860  FINANCIERA OH! SA O FINANCIERA OH SA    20522291201
# 655428      BANCO INTERAMERICANO DE FINANZAS    20101036813
# 286265      AUTOMOTORES GILDEMEISTER-PERU SA    20506006024
#
#             EXPEDIENTE_ORIGEN_pres FECHA_PRESENTACION FECHA_RESOLUCION  \
# 209492           0183-2019/CC3-SIA         2020-09-30       2020-11-24
# 922812               0747-2019/CC1         2020-01-10       2020-02-10
# 230860               0252-2020/CC1         2021-05-17       2021-08-04
# 655428  0074-2017/CPC-INDECOPI-AQP         2017-11-07       2018-04-23
# 286265           0073-2017/ILN-CPC         2017-12-27       2018-06-20
#
#        FORMA_CONCLUSION                                        MATERIA  \
# 209492         CONFIRMA                        TRANSPORTE DE PASAJEROS
# ...

# %%
data_s.sample(5)
# Out:
#                                             DENUNCIADOS DOC_DENUNCIADO  \
# 73450                         BANCO DE CREDITO DEL PERU    20100047218
# 181180  MAPFRE PERU COMPANIA DE SEGUROS Y REASEGUROS SA    20202380621
# 944844                          CENCOSUD RETAIL PERU SA    20109072177
# 780991                              SCOTIABANK PERU SAA    20100043140
# 470729                              Grupo Comercial SAC    20263827776
#
#             EXPEDIENTE_ORIGEN_pres FECHA_PRESENTACION FECHA_RESOLUCION  \
# 73450   0204-2019/CPC-INDECOPI-LAL         2020-12-21       2021-06-02
# 181180               0592-2017/CC1         2018-03-09       2018-09-03
# 944844  0137-2019/CPC-INDECOPI-AQP         2020-10-15       2020-11-19
# 780991               0751-2018/CC1         2018-11-19       2019-04-29
# 470729               0954-2020/CC2         2021-09-29       2021-10-20
#
#                             FORMA_CONCLUSION                 MATERIA  \
# ...
